# %% [markdown]
# ## Relationships in Data

# %% [markdown]
# ## Work By-
# ### Ravjot Singh
# - LinkedIn: https://www.linkedin.com/in/ravjot03/
# - Github: https://github.com/Ravjot03
# - Medium: https://ravjot03.medium.com/
# - Email: ravjot313@gmail.com
# - Mobile: +1(341)-345-1373 (USA)
# - Location: San Francisco, California, USA

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the data

# %%
df = pd.read_csv('divorce.csv')

# %% [markdown]
# Initital Exploration of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   divorce_date       2209 non-null   object
#  1   dob_man            2209 non-null   object
#  2   education_man      2205 non-null   object
#  3   income_man         2209 non-null   float64
#  4   dob_woman          2209 non-null   object
#  5   education_woman    2209 non-null   object
#  6   income_woman       2209 non-null   float64
#  7   marriage_date      2209 non-null   object
#  8   marriage_duration  2209 non-null   float64
#  9   num_kids           1333 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 172.7+ KB

# %%
df.head()
# Out:
#   divorce_date     dob_man education_man  income_man   dob_woman  \
# 0   2006-09-06  1975-12-18     Secondary      2000.0  1983-08-01
# 1   2008-01-02  1976-11-17  Professional      6000.0  1977-03-13
# 2   2011-01-02  1969-04-06   Preparatory      5000.0  1970-02-16
# 3   2011-01-02  1979-11-13     Secondary     12000.0  1981-05-13
# 4   2011-01-02  1982-09-20  Professional      6000.0  1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN

# %%
df.describe()
# Out:
#          income_man  income_woman  marriage_duration     num_kids
# count   2209.000000   2209.000000        2209.000000  1333.000000
# mean    7922.986410   6793.164545           9.606609     1.672918
# std     7693.796497   6562.928689           7.266696     0.732858
# min        3.000000      3.500000           1.000000     1.000000
# 25%     3600.000000   3000.000000           4.000000     1.000000
# 50%     6000.000000   5000.000000           8.000000     2.000000
# 75%    10000.000000   8000.000000          14.000000     2.000000
# max    80000.000000  90000.000000          32.000000     5.000000

# %%
df.shape
# Out:
# (2209, 10)

# %% [markdown]
# Counting Missing values in each column in data

# %%
df.isna().sum().sort_values()
# Out:
# divorce_date           0
# dob_man                0
# income_man             0
# dob_woman              0
# education_woman        0
# income_woman           0
# marriage_date          0
# marriage_duration      0
# education_man          4
# num_kids             876
# dtype: int64

# %% [markdown]
# Converting arguments to datetime data

# %%
df['divorce_date'] = pd.to_datetime(df['divorce_date'])
df['marriage_date'] = pd.to_datetime(df['marriage_date'])
df['dob_man'] = pd.to_datetime(df['dob_man'])
df['dob_woman'] = pd.to_datetime(df['dob_woman'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   divorce_date       2209 non-null   datetime64[ns]
#  1   dob_man            2209 non-null   datetime64[ns]
#  2   education_man      2205 non-null   object
#  3   income_man         2209 non-null   float64
#  4   dob_woman          2209 non-null   datetime64[ns]
#  5   education_woman    2209 non-null   object
#  6   income_woman       2209 non-null   float64
#  7   marriage_date      2209 non-null   datetime64[ns]
#  8   marriage_duration  2209 non-null   float64
#  9   num_kids           1333 non-null   float64
# dtypes: datetime64[ns](4), float64(4), object(2)
# memory usage: 172.7+ KB

# %% [markdown]
# Extracting parts of a full date using dt.month, dt.day, and dt.year attributes

# %%
df['marriage_month'] = df['marriage_date'].dt.month
df['marriage_day'] = df['marriage_date'].dt.day
df['marriage_year'] = df['marriage_date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   divorce_date       2209 non-null   datetime64[ns]
#  1   dob_man            2209 non-null   datetime64[ns]
#  2   education_man      2205 non-null   object
#  3   income_man         2209 non-null   float64
#  4   dob_woman          2209 non-null   datetime64[ns]
#  5   education_woman    2209 non-null   object
#  6   income_woman       2209 non-null   float64
#  7   marriage_date      2209 non-null   datetime64[ns]
#  8   marriage_duration  2209 non-null   float64
#  9   num_kids           1333 non-null   float64
#  10  marriage_month     2209 non-null   int32
#  11  marriage_day       2209 non-null   int32
#  12  marriage_year      2209 non-null   int32
# dtypes: datetime64[ns](4), float64(4), int32(3), object(2)
# memory usage: 198.6+ KB

# %% [markdown]
# A. Visualizing time series patterns
#
# Line plots are a great way to examine relationships between variables. In Seaborn library, line plots aggregate y values at each value of x and show the estimated mean and a confidence interval for that estimate.

# %%
sns.lineplot(data=df, x='marriage_month', y='marriage_duration')
plt.show()

# %% [markdown]
# Conclusion - Above we are checking whether there is any relationship between the month that a now - divorced couple got married and the length of their marriage. We can set x = marriage_month column and y = marriage_duration.
#
# The results show some variation in mean marriage duration between months. The blue line represents the mean marriage duration for the dataset, while the confidence intervals in the lighter blue shading indicate the area that, with 95% probability, the population mean duration could fall between. The wide confidence intervals suggest that further analysis is needed.

# %% [markdown]
# B. Correlation
#
# Correlation describes the direction of the relationship between two variables as well as its strength. Understanding this relationship can help us use variables to predict future outcomes.

# %% [markdown]
# A quick way to see the pairwise correlation of numeric columns in a DataFrame is to use df.corr().
#
# A negative correlation coefficient indicates that as one variable increases, the other decreases. A value closer to zero is indicative of a weak relationship, while values closer to one or negative one indicate stronger relationships.

# %%
df.corr(numeric_only=True)
# Out:
#                    income_man  income_woman  marriage_duration  num_kids  \
# income_man           1.000000      0.318047           0.085321  0.040848
# income_woman         0.318047      1.000000           0.078677 -0.018015
# marriage_duration    0.085321      0.078677           1.000000  0.447358
# num_kids             0.040848     -0.018015           0.447358  1.000000
# marriage_month       0.013652      0.041441           0.001433 -0.000551
# marriage_day        -0.006635      0.069475           0.015322  0.019353
# marriage_year        0.019170      0.026433          -0.812469 -0.461495
#
#                    marriage_month  marriage_day  marriage_year
# income_man               0.013652     -0.006635       0.019170
# income_woman             0.041441      0.069475       0.026433
# marriage_duration        0.001433      0.015322      -0.812469
# num_kids                -0.000551      0.019353      -0.461495
# marriage_month           1.000000     -0.013650      -0.011456
# ...

# %% [markdown]
# A heatmap has the benefit of color coding so that strong positive and negative correlations, represented in deep purple and beige respectively, are easier to spot.
#
# - Setting the annot argument equals to True; labels the correlation coefficient inside each cell.
#
# Conclusion - We can conclude that marriage year and marriage duration are strongly negatively correlated; in our data, marriages in later years are typically shorter.

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
df['divorce_date'].min()
# Out:
# Timestamp('2000-01-08 00:00:00')

# %%
df['divorce_date'].max()
# Out:
# Timestamp('2015-11-03 00:00:00')

# %%
df['marriage_date'].min()
# Out:
# Timestamp('1970-01-15 00:00:00')

# %%
df['marriage_date'].max()
# Out:
# Timestamp('2014-02-14 00:00:00')

# %%
sns.scatterplot(data=df, x='income_man', y='income_woman')
plt.show()

# %% [markdown]
# Conclusion - For example, the monthly income of the female partner and the male partner at the time of divorce showed a correlation coefficient of 0.32 in our heatmap.
#
# Let's check it using Seaborn's scatterplot -  this correctly indicates a small positive relationship between the two variables by passing them as x and y arguments to Seaborn's scatterplot function. It looks like the relationship exists but is not particularly strong, just as the heatmap suggested.

# %%
sns.catplot(data=df, kind='count', x='num_kids')
plt.show()
# Out:
# /Users/ravjotsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Conclusion - Above countplot shows the Number of kids distribution from our dataset.

# %%
sns.pairplot(data=df)
plt.show()
# Out:
# /Users/ravjotsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Conclusion - We can take the scatterplots to the next level with Seaborn's pairplot function.
#
# When passed a pandas dataframe, pairplot plots all pairwise relationships between numerical variables in one visualization.
#
# - On the diagonal from upper left to lower right, we can clearly see the distribution of each variable's observations. This is useful for a quick overview of relationships within the dataset.
#
# - However, having this much information in one visual can be difficult to interpret, especially with large datasets which lead to very small plot labels like these ones.

# %%
sns.pairplot(data=df, vars=['income_man', 'income_woman','marriage_duration'])
plt.show()
# Out:
# /Users/ravjotsingh/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Conclusion - We can also limit the number of plotted relationships by setting the vars argument equal to the variables of interest from our dataset.

# %% [markdown]
# C. Exploring categorical variables

# %%
sns.histplot(data=df, x='marriage_duration', binwidth=1)
plt.show()

# %% [markdown]
# Categorical variables are harder to summarize numerically, so we often rely on visualizations to explore their relationships.
# Above we have plotted a histogram of the distribution of marriage duration.

# %%
sns.histplot(data=df, x='marriage_duration', hue='education_man', binwidth=1)
plt.show()

# %% [markdown]
# Conclusion - The above histogram reinforces what we saw in value_counts: we have a lot of information on males with professional-level education. However, because the education levels are stacked on top of each other, it is not clear to get some relationship insights b/w marriage_duration and education_man column.

# %%
sns.histplot(data=df, x='marriage_duration', hue='education_woman', binwidth=1)
plt.show()

# %% [markdown]
# D. Kernel Density Estimate (KDE) plots
#
# Seaborn's Kernel Density Estimate or KDE plots addresses the issue, we are facing above to find relationships b/w variables.
#
# Similar to histograms, KDE's allows to visualize distributions. KDE's are considered more interpretable, though, especially when multiple distributions are shown below.
#
# Conclusion - Now notice that the location of the peak marriage duration for each level of the male partner's education is more identifiable in this KDE plot than it was in the histogram. However, due to the smoothing algorithm used in KDE plots, the curve can include values that don't make sense, so it's important to set good smoothing parameters.

# %%
sns.kdeplot(data=df, x='marriage_duration', hue='education_man')
plt.show()

# %% [markdown]
# To fix the issue as seen in above plot that some couples had marriage durations of less than zero.
#
# We can use the cut keyword argument. "cut" tells Seaborn how far past the minimum and maximum data values the curve should go when smoothing is applied. When we set cut = zero, the curve will be limited to values between the minimum and maximum x values, here, the minimum and maximum values for marriage duration. The plot shows only marriage durations greater than or equal to one year, the shortest marriage duration in the data.

# %%
sns.kdeplot(data=df, x='marriage_duration', hue='education_man', cut=0)
plt.show()

# %% [markdown]
# Cumulative KDE Plot:
# To plot the cumulative distribution function, we can set the cumulative =  True. This graph describes the probability that marriage duration is less than or equal to the value on the x-axis for each level of male partner education.

# %%
sns.kdeplot(data=df, x='marriage_duration', hue='education_man', cut=0, cumulative=True)
plt.show()

# %% [markdown]
# We can create more columns representing the approximate age at marriage for men and women by subtracting each partner's birth year from the marriage year.

# %%
df['man_marriage_age'] = df['marriage_year'] - df['dob_man'].dt.year
df['woman_marriage_age'] = df['marriage_year'] - df['dob_woman'].dt.year

# %%
df.head()
# Out:
#   divorce_date    dob_man education_man  income_man  dob_woman  \
# 0   2006-09-06 1975-12-18     Secondary      2000.0 1983-08-01
# 1   2008-01-02 1976-11-17  Professional      6000.0 1977-03-13
# 2   2011-01-02 1969-04-06   Preparatory      5000.0 1970-02-16
# 3   2011-01-02 1979-11-13     Secondary     12000.0 1981-05-13
# 4   2011-01-02 1982-09-20  Professional      6000.0 1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids  \
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN
#
#    marriage_month  marriage_day  marriage_year  man_marriage_age  \
# 0               6            26           2000                25
# ...

# %%
sns.scatterplot(data=df, x='man_marriage_age', y='woman_marriage_age')
plt.show()

# %%
sns.scatterplot(data=df, x='man_marriage_age', y='woman_marriage_age', hue='num_kids')
plt.show()

# %%
sns.scatterplot(data=df, x='man_marriage_age', y='woman_marriage_age', hue='education_man')
plt.show()

# %% [markdown]
# Conclusion - In the above scatterplot, we set hue equal to education_man.
#
# The result conclude that the men with a professional education level, represented with orange dots, may tend to get married later.

# %%
sns.scatterplot(data=df, x='man_marriage_age', y='woman_marriage_age', hue='education_woman')
plt.show()
